# %% [markdown]
# # Accuracy versus energy
# Goals=Compare energy consumed versus learning advancement.
#
# No information on training accuracy, only evaluations.
#
# ToDo:
# - compute total energy timeserie
# - plot in parallel with accuracy
# - compute energy between each eval

# %%
import pandas as pd
# import modin.pandas as pd
import dask.dataframe as dd
import matplotlib.pyplot as plt
import seaborn as sns

logs = # TO FILL
graph_dir = f"{logs}/graphs/accuracy"
processed_log_dir = f"{logs}/resultats_11-23_processed"
log_dir = f"{logs}/resultats_11-23/"
save_dir = f"{processed_log_dir}/rnnt/"
path = f"{log_dir}/rnnt/"

job_file = save_dir+"/summary.csv"
energy_file = save_dir+"/energy.csv"

# energy = dd.read_csv(
#     energy_file, 
#     dtype={'cpu': 'object', 'socket': 'object', 'domain': 'object'}).drop(columns=["Unnamed: 0"])
# energy.to_parquet(save_dir+'energy.parquet', engine='pyarrow')
energy = dd.read_parquet(save_dir+'energy.parquet', engine='pyarrow')
jobs = pd.read_csv(job_file).drop(columns=["Unnamed: 0"])

# %%
# jobs = jobs[jobs["job"]>126990]
jobs[:1]
# Out:
#       job  energy_kWh  energy_joule  \
# 0  126701    2.153195  7.751502e+06
#
#    energy_consumption_since_previous_measurement_milliJ  job_id  \
# 0                                       7.751502e+09     126701
#
#                                                 file  sub_seed  \
# 0  /Users/mathildepro/Documents/code_projects/hpe...        51
#
#    srun_start_time_ms  start_time_ms  training_start_time_ms  ...  \
# 0        1.699464e+12   1.699464e+12            1.699464e+12  ...
#
#    mllog_opt_lamb_beta_1  mllog_opt_lamb_beta_2  mllog_opt_gradient_clip_norm  \
# 0                    0.9                  0.999                             1
#
#    mllog_opt_learning_rate_alt_decay_func  \
# 0                                    True
#
#    mllog_opt_learning_rate_alt_warmup_func  mllog_opt_lamb_learning_rate_min  \
# 0                                     True                           0.00001
#
#    mllog_opt_weight_decay  mllog_throughput  mllog_eval_accuracy  node_nb
# 0                   0.001       6804.870687             0.057884        1
#
# [1 rows x 83 columns]

# %%
job = 126701
plot_df = jobs[(jobs["job"]==job)]

# %%
file = plot_df.file.values[0]
file.split("/")[-2:]
# Out:
# ['126701', '231108181721312636982_1.log']

# %%
import sys
sys.path.append("../../logging/mlperf_logging/")

from compliance_checker.mlp_parser import parse_file


log_file = path + "/".join(file.split("/")[-2:])
print(log_file)

loglines, _ = parse_file(log_file, ruleset="2.1.0")
mllog = pd.json_normalize(pd.DataFrame(loglines)["value"])
mllog = mllog.merge(pd.DataFrame(loglines)[["timestamp", "key"]], left_index=True, right_index=True)
# Out:
# /Users/mathildepro/Documents/code_projects/logs/Apollo/resultats_11-23//rnnt/126701/231108181721312636982_1.log

# %%
mllog = mllog.drop(['metadata.file', 'metadata.lineno', 'metadata.tensor', 'metadata.status'], axis=1)

# %%
mllog.columns
# Out:
# Index(['value', 'metadata.first_epoch_num', 'metadata.epoch_count',
#        'metadata.epoch_num', 'timestamp', 'key'],
#       dtype='object')

# %%
pd.set_option('display.max_colwidth', 15)
pd.set_option('display.max_rows', 67)
table = mllog[mllog["value"].notna()].dropna(axis=1,how='all')
cols = [x for x in table.columns] # if (x != "full_string") and (x != "metadata")]
table[cols].style.background_gradient(cmap='viridis', low=0.2, high=0.2, axis=0)
{
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_d8520_row36_col2, #T_d8520_row37_col2 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_d8520_row38_col2, #T_d8520_row39_col2 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_d8520_row39_col1 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_d8520_row40_col2, #T_d8520_row41_col2 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_d8520_row41_col1 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_d8520_row42_col2, #T_d8520_row43_col2 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_d8520_row43_col1 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_d8520_row44_col2, #T_d8520_row45_col2 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_d8520_row45_col1 {
#   background-color: #414287;
#   color: #f1f1f1;
# }
# #T_d8520_row46_col2, #T_d8520_row47_col2, #T_d8520_row53_col1 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_d8520_row47_col1 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_d8520_row48_col2, #T_d8520_row49_col2 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_d8520_row49_col1 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_d8520_row50_col2, #T_d8520_row51_col2, #T_d8520_row57_col1 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_d8520_row51_col1 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_d8520_row52_col2, #T_d8520_row53_col2, #T_d8520_row59_col1 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_d8520_row54_col2, #T_d8520_row55_col2 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_d8520_row55_col1 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_d8520_row56_col2, #T_d8520_row57_col2, #T_d8520_row63_col1 {
#   background-color: #32648e;
#   color: #f1f1f1;
# }
# #T_d8520_row58_col2, #T_d8520_row59_col2, #T_d8520_row65_col1 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_d8520_row60_col2, #T_d8520_row61_col2 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_d8520_row61_col1 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_d8520_row62_col2, #T_d8520_row63_col2, #T_d8520_row69_col1 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_d8520_row64_col2, #T_d8520_row65_col2 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_d8520_row66_col2, #T_d8520_row67_col2 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_d8520_row67_col1 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_d8520_row68_col2, #T_d8520_row69_col2 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_d8520_row70_col2, #T_d8520_row71_col2 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_d8520_row71_col1 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_d8520_row72_col2, #T_d8520_row73_col2 {
#   background-color: #287d8e;
#   color: #f1f1f1;
# }
# #T_d8520_row73_col1 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_d8520_row74_col2, #T_d8520_row75_col2 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_d8520_row75_col1 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_d8520_row76_col2, #T_d8520_row77_col2, #T_d8520_row81_col1 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_d8520_row77_col1 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_d8520_row78_col2, #T_d8520_row79_col2 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_d8520_row79_col1 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_d8520_row80_col2, #T_d8520_row85_col1 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_d8520_row81_col2 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_d8520_row82_col2, #T_d8520_row83_col2 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_d8520_row83_col1 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_d8520_row84_col2, #T_d8520_row85_col2, #T_d8520_row89_col1 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_d8520_row86_col2, #T_d8520_row87_col2, #T_d8520_row91_col1 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_d8520_row87_col1 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_d8520_row88_col2, #T_d8520_row89_col2 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_d8520_row90_col2, #T_d8520_row91_col2, #T_d8520_row95_col1 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_d8520_row92_col2, #T_d8520_row93_col2 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_d8520_row93_col1 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_d8520_row94_col2, #T_d8520_row95_col2 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_d8520_row96_col2, #T_d8520_row97_col2 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_d8520_row97_col1 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_d8520_row98_col2, #T_d8520_row99_col2 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_d8520_row99_col1 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_d8520_row100_col2, #T_d8520_row101_col2 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_d8520_row101_col1 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_d8520_row102_col2, #T_d8520_row103_col2 {
#   background-color: #24aa83;
#   color: #f1f1f1;
# }
# #T_d8520_row103_col1 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_d8520_row104_col2, #T_d8520_row105_col2 {
#   background-color: #26ad81;
#   color: #f1f1f1;
# }
# #T_d8520_row105_col1 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_d8520_row10

# %%
import itertools
import numpy as np
keys = ['eval_accuracy', 'eval_samples', 'global_batch_size',
       'gradient_accumulation_steps', 'init_start', 'init_stop',
       'run_start', 'run_stop', 
       'submission_benchmark', #'submission_division', 'submission_org', 'submission_platform','submission_status', 
       'train_samples', 'weights_initialization']

fig, ax = plt.subplots(figsize=(20,10))
ax2 = ax.twinx()
energy[energy["job"]==job].sort_values(by="timestamp").groupby("timestamp")[["energy_consumption_since_previous_measurement_milliJ"]].sum().compute().plot(ax=ax,y="energy_consumption_since_previous_measurement_milliJ", color="blue", alpha=0.5)
ax.set_ylabel("Power (kW)")

COLOR = plt.cm.tab10
iter = itertools.cycle(COLOR(np.linspace(0, 1, len(keys))))
ymin = 1e5
size = 3e5
for key in keys:
    color = next(iter)
    ax.vlines(x=mllog[mllog["key"]==key]["timestamp"], ymin=ymin, ymax=ymin+size, color=color, linewidth=3, label=key)
    ymin+=size
ax.legend(loc='upper left', bbox_to_anchor=(1.05, 1), fontsize=14)

ax.vlines(x=jobs[jobs["job"]==job]["start_time_ms"], ymin=0, ymax=size, color="red", linewidth=3, label="Accuracy")
ax.vlines(x=jobs[jobs["job"]==job]["end_time_ms"], ymin=0, ymax=size, color="red", linewidth=3, label="Accuracy")

mllog[mllog["key"]=="eval_accuracy"][["timestamp", "value"]].plot(ax=ax2,x="timestamp", y="value", label="Accuracy", color="orange", linewidth=3)
ax2.set_ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# # For all jobs

# %%
def compute_energy_between_accuracies(row):
        """Compute energy between two accuracy values."""
        mask = (energy["timestamp"]>=row["timestamp"]-row["time_diff"])&(energy["timestamp"]<=row["timestamp"])
        energy_between_accuracies = energy[mask]["energy_kWh"].sum().compute()
        return energy_between_accuracies

accuracy_df = pd.DataFrame()

for job in jobs["job"].unique()[-10:]:
    file = jobs[jobs["job"]==job]["file"].values[0]
    file.split("/")[-2:]    
    log_file = path + "/".join(file.split("/")[-2:])

    loglines, _ = parse_file(log_file, ruleset="2.1.0")
    mllog = pd.json_normalize(pd.DataFrame(loglines)["value"])
    mllog = mllog.merge(pd.DataFrame(loglines)[["timestamp", "key"]], left_index=True, right_index=True)

    acc_df = mllog[mllog["key"]=="eval_accuracy"][["timestamp", "value"]].reset_index(drop=True)
    acc_df["time_diff"] = acc_df["timestamp"].diff()
    acc_df["acc_diff"] = acc_df["value"].diff()
    acc_df.rename(columns={"value":"accuracy"}, inplace=True)
    acc_df.at[0, "acc_diff"] = acc_df.at[0, "accuracy"]
    first_timestamp = acc_df.at[0, "timestamp"]
    run_start = mllog[mllog["key"]=='run_start']["timestamp"].values[0]
    acc_df.at[0, "time_diff"] = first_timestamp - run_start
    acc_df["energy_kWh"] = acc_df.apply(compute_energy_between_accuracies, axis=1)
    acc_df["energy_kWh_cumsum"] = acc_df["energy_kWh"].cumsum()
    acc_df["job"] = job
    
    accuracy_df = pd.concat([accuracy_df, acc_df])

# %%
accuracy_job = accuracy_df.merge(jobs, on="job", how="left")

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.style.use('seaborn-v0_8-whitegrid')

tex_fonts = {
    # Use LaTeX to write all text
    "text.usetex": True,
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 10,
    "font.size": 10,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 8,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8
}

plt.rcParams.update(tex_fonts)

plt.figure(figsize=(15,8))
ax = sns.relplot(
    x="accuracy", y="energy_kWh_cumsum",
    data=accuracy_job, 
    hue="job", kind="line", 
    palette="tab10",
    height=3, aspect=12/8,alpha=0.7,
    )# ax.set(title="Power consumption of dlrm training")
ax._legend.remove()
FONTSIZE = 12
ax.set_xlabels("Word Error Rate", fontsize=FONTSIZE)
ax.set_ylabels("Accumulated energy (kWh)", fontsize=FONTSIZE)
ax.set_xticklabels(fontsize=FONTSIZE)
ax.set_yticklabels(fontsize=FONTSIZE)
ax.savefig(f"{graph_dir}/rnnt.pdf", dpi=300)
# Out:
# /Users/mathildepro/miniforge3/envs/energy_analysis/lib/python3.10/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
